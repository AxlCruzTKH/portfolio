# %% [markdown]
# # Table Styling in Pandas

# %%
# Pandas can Style Dataframes in a unique way. It does so by creating
# The DataFrame object, transforming it into an HTML table, and then
# Styling the table by applying HTML and CSS to it. It allows
# For a ton of useful and powerful operation out of the box.

#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.io.formats.style.Styler.html
#

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

df = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, np.nan],[19, 439, 6, 452, 226,232]],
                  index=pd.Index(['Tumour (Positive)', 'Non-Tumour (Negative)'], name='Actual Label:'),
                  columns=pd.MultiIndex.from_product([['Decision Tree', 'Regression', 'Random'],['Tumour', 'Non-Tumour']], names=['Model:', 'Predicted:']))
df.style
df


### Here we have a multidimensional object.

## We have a table made up of three subtables, which each contain 2 Series.
## Let's get some practice in selecting from Multidimensional Objects.
# Out:
# Model:                Decision Tree            Regression            Random  \
# Predicted:                   Tumour Non-Tumour     Tumour Non-Tumour Tumour
# Actual Label:
# Tumour (Positive)              38.0        2.0       18.0       22.0     21
# Non-Tumour (Negative)          19.0      439.0        6.0      452.0    226
#
# Model:
# Predicted:            Non-Tumour
# Actual Label:
# Tumour (Positive)            NaN
# Non-Tumour (Negative)      232.0

# %%
df.style.format(precision=0, na_rep='MISSING', thousands=" ",
                formatter={('Decision Tree', 'Tumour'): "{:.2f}",
                           ('Regression', 'Non-Tumour'): lambda x: "$ {:,.1f}".format(x*-1e6)
                          })
# Out:
# <style type="text/css">
# </style>
# <table id="T_2ce46">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_2ce46_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_2ce46_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_2ce46_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_2ce46_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_2ce46_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_2ce46_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_2ce46_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_2ce46_level1_col4" class="col_heading level1 col4" >Tumour</th>
#       <th id="T_2ce46_level1_col5" class="col_heading level1 col5" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ce46_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_2ce46_row0_col0" class="data row0 col0" >38.00</td>
#       <td id="T_2ce46_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_2ce46_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_2ce46_row0_col3" class="data row0 col3" >$ -22 000 000.0</td>
#       <td id="T_2ce46_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_2ce46_row0_col5" class="data row0 col5" >MISSING</td>
#     </tr>
#     <tr>
#       <th id="T_2ce46_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_2ce46_row1_col0" class="data row1 col0" >19.00</td>
#       <td id="T_2ce46_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_2ce46_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_2ce46_row1_col3" class="data row1 col3" >$ -452 000 000.0</td>
#       <td id="T_2ce46_row1_col4" class="data row1 col4" >226</td>
#       <td id="T_2ce46_row1_col5" class="data row1 col5" >232</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2021-01-01", periods=10),
                          columns=["Tokyo", "Beijing"])

def rain_condition(v):
    if v < 1.75:
        return "Dry"
    elif v < 2.75:
        return "Rain"
    return "Heavy Rain"

def make_pretty(styler):
    styler.set_caption("Weather Conditions")
    styler.format(rain_condition)
    styler.format_index(lambda v: v.strftime("%A"))
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlGnBu")
    return styler

weather_df
# Out:
#                Tokyo   Beijing
# 2021-01-01  1.403938  0.487749
# 2021-01-02  1.465315  4.279550
# 2021-01-03  2.791370  4.793065
# 2021-01-04  1.981330  1.111612
# 2021-01-05  0.562050  0.418163
# 2021-01-06  1.273664  0.164858
# 2021-01-07  3.134525  3.459481
# 2021-01-08  0.657351  2.788994
# 2021-01-09  2.109224  1.251847
# 2021-01-10  3.310261  3.265908

# %%
weather_df.loc["2021-01-04":"2021-01-08"].style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_76fa5_row0_col0 {
#   background-color: #c9eab4;
#   color: #000000;
# }
# #T_76fa5_row0_col1 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_76fa5_row1_col0, #T_76fa5_row1_col1, #T_76fa5_row2_col1, #T_76fa5_row4_col0 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_76fa5_row2_col0 {
#   background-color: #f5fbc4;
#   color: #000000;
# }
# #T_76fa5_row3_col0 {
#   background-color: #37acc3;
#   color: #f1f1f1;
# }
# #T_76fa5_row3_col1 {
#   background-color: #2094c0;
#   color: #f1f1f1;
# }
# #T_76fa5_row4_col1 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# </style>
# <table id="T_76fa5">
#   <caption>Weather Conditions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76fa5_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_76fa5_level0_col1" class="col_heading level0 col1" >Beijing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76fa5_level0_row0" class="row_heading level0 row0" >Monday</th>
#       <td id="T_76fa5_row0_col0" class="data row0 col0" >Rain</td>
#       <td id="T_76fa5_row0_col1" class="data row0 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_76fa5_level0_row1" class="row_heading level0 row1" >Tuesday</th>
#       <td id="T_76fa5_row1_col0" class="data row1 col0" >Dry</td>
#       <td id="T_76fa5_row1_col1" class="data row1 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_76fa5_level0_row2" class="row_heading level0 row2" >Wednesday</th>
#       <td id="T_76fa5_row2_col0" class="data row2 col0" >Dry</td>
#       <td id="T_76fa5_row2_col1" class="data row2 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_76fa5_level0_row3" class="row_heading level0 row3" >Thursday</th>
#       <td id="T_76fa5_row3_col0" class="data row3 col0" >Heavy Rain</td>
#       <td id="T_76fa5_row3_col1" class="data row3 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_76fa5_level0_row4" class="row_heading level0 row4" >Friday</th>
#       <td id="T_76fa5_row4_col0" class="data row4 col0" >Dry</td>
#       <td id="T_76fa5_row4_col1" class="data row4 col1" >Heavy Rain</td>
#     </tr>
#   </tbody>
# </table>

# %%
#import pandas as pd

#pd.__version__

#!pip install --upgrade pandas
#pip install upgrade pandas

#import sys
#!{sys.executable} -m pip install numpy

# %% [markdown]
# # Hiding Data

# %%
s = df.style.format('{:.0f}').hide([('Random', 'Tumour'), ('Random', 'Non-Tumour')], axis="columns")
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_23197">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_23197_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_23197_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_23197_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_23197_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_23197_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_23197_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23197_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_23197_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_23197_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_23197_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_23197_row0_col3" class="data row0 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_23197_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_23197_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_23197_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_23197_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_23197_row1_col3" class="data row1 col3" >452</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Index and Column Headers can be hidden as well as explicit row/columns.

#Index can be hidden by calling .hide() with no arguments
#Columns can be hidden by calling .hide(axis="columns")
#Rows and Columns can be selected by passing row names, Column names, or lists.
#The values are still there, just not being displayed.

# %%
s = df.style.format('{:.0f}')


s
# Out:
# <style type="text/css">
# </style>
# <table id="T_7f28e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_7f28e_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_7f28e_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_7f28e_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_7f28e_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_7f28e_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_7f28e_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_7f28e_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_7f28e_level1_col4" class="col_heading level1 col4" >Tumour</th>
#       <th id="T_7f28e_level1_col5" class="col_heading level1 col5" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f28e_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_7f28e_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_7f28e_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_7f28e_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_7f28e_row0_col3" class="data row0 col3" >22</td>
#       <td id="T_7f28e_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_7f28e_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7f28e_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_7f28e_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_7f28e_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_7f28e_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_7f28e_row1_col3" class="data row1 col3" >452</td>
#       <td id="T_7f28e_row1_col4" class="data row1 col4" >226</td>
#       <td id="T_7f28e_row1_col5" class="data row1 col5" >232</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Adding Styles to Tables

# %%
cell_hover = {  # for row hover use <tr> instead of <td>
    'selector': 'td:hover',
    #On Cell Hover
    'props': [('background-color', '#ffffb3')]
    #Change color to this
}
index_names = {
    #Change the index names font-styling
    'selector': '.index_name',
    'props': 'font-style: italic; color: darkgrey; font-weight:normal;'
}
headers = {
    #Change the table headers except the index_names
    'selector': 'th:not(.index_name)',
    'props': 'background-color: #000066; color: white;'
}
s.set_table_styles([cell_hover, index_names, headers])
# Out:
# <style type="text/css">
# #T_7f28e td:hover {
#   background-color: #ffffb3;
# }
# #T_7f28e .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_7f28e th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# </style>
# <table id="T_7f28e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_7f28e_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_7f28e_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_7f28e_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_7f28e_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_7f28e_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_7f28e_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_7f28e_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_7f28e_level1_col4" class="col_heading level1 col4" >Tumour</th>
#       <th id="T_7f28e_level1_col5" class="col_heading level1 col5" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f28e_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_7f28e_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_7f28e_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_7f28e_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_7f28e_row0_col3" class="data row0 col3" >22</td>
#       <td id="T_7f28e_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_7f28e_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7f28e_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_7f28e_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_7f28e_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_7f28e_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_7f28e_row1_col3" class="data row1 col3" >452</td>
#       <td id="T_7f28e_row1_col4" class="data row1 col4" >226</td>
#       <td id="T_7f28e_row1_col5" class="data row1 col5" >232</td>
#     </tr>
#   </tbody>
# </table>

# %%
s.set_table_styles([
    {'selector': 'th.col_heading', 'props': 'text-align: center;'},
    # Select ALL the column headings, align their text.
    {'selector': 'th.col_heading.level0', 'props': 'font-size: 1.5em;'},
    # Select the highest level heading and apply these changes
    {'selector': 'td', 'props': 'text-align: center; font-weight: bold;'},
    #Select the rows, align their text and weigh their text.
], overwrite=False
    #Keep the previous stylings.

)
# Out:
# <style type="text/css">
# #T_7f28e td:hover {
#   background-color: #ffffb3;
# }
# #T_7f28e .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_7f28e th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_7f28e th.col_heading {
#   text-align: center;
# }
# #T_7f28e th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_7f28e td {
#   text-align: center;
#   font-weight: bold;
# }
# </style>
# <table id="T_7f28e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_7f28e_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_7f28e_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_7f28e_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_7f28e_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_7f28e_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_7f28e_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_7f28e_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_7f28e_level1_col4" class="col_heading level1 col4" >Tumour</th>
#       <th id="T_7f28e_level1_col5" class="col_heading level1 col5" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f28e_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_7f28e_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_7f28e_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_7f28e_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_7f28e_row0_col3" class="data row0 col3" >22</td>
#       <td id="T_7f28e_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_7f28e_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7f28e_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_7f28e_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_7f28e_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_7f28e_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_7f28e_row1_col3" class="data row1 col3" >452</td>
#       <td id="T_7f28e_row1_col4" class="data row1 col4" >226</td>
#       <td id="T_7f28e_row1_col5" class="data row1 col5" >232</td>
#     </tr>
#   </tbody>
# </table>

# %%
s.set_table_styles([
    {'selector':'th.col_heading.level0','props':'border-bottom:1px solid white'}
    ], overwrite=False, axis=0)
# Out:
# <style type="text/css">
# #T_7f28e td:hover {
#   background-color: #ffffb3;
# }
# #T_7f28e .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_7f28e th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_7f28e th.col_heading {
#   text-align: center;
# }
# #T_7f28e th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_7f28e td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_7f28e th.col_heading.level0 {
#   border-bottom: 1px solid white;
# }
# </style>
# <table id="T_7f28e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_7f28e_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_7f28e_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_7f28e_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_7f28e_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_7f28e_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_7f28e_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_7f28e_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_7f28e_level1_col4" class="col_heading level1 col4" >Tumour</th>
#       <th id="T_7f28e_level1_col5" class="col_heading level1 col5" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f28e_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_7f28e_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_7f28e_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_7f28e_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_7f28e_row0_col3" class="data row0 col3" >22</td>
#       <td id="T_7f28e_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_7f28e_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7f28e_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_7f28e_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_7f28e_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_7f28e_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_7f28e_row1_col3" class="data row1 col3" >452</td>
#       <td id="T_7f28e_row1_col4" class="data row1 col4" >226</td>
#       <td id="T_7f28e_row1_col5" class="data row1 col5" >232</td>
#     </tr>
#   </tbody>
# </table>

# %%
s.set_table_styles({
    ('Regression','Tumour'): [{'selector': 'th', 'props': 'border-left: 1px solid white; border-right: 1px solid white'},
                               {'selector': 'td', 'props': 'border-left: 1px solid #000066; border-right: 1px solid #000066'},
                                ],
    ('Regression','Non-Tumour'): [{'selector': 'th', 'props': 'border-left: 1px solid white; border-right: 1px solid white'},
                                    {'selector': 'td', 'props':'border-right: 1px solid #000066'},
                                ],
    
}, overwrite=False, axis=0)
s.set_table_styles({
('Tumour (Positive)'): [{'selector':'tr','props':'border-bottom:1px solid black'}]
 },axis=1, overwrite=False)
s
# Out:
# <style type="text/css">
# #T_7f28e td:hover {
#   background-color: #ffffb3;
# }
# #T_7f28e .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_7f28e th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_7f28e th.col_heading {
#   text-align: center;
# }
# #T_7f28e th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_7f28e td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_7f28e th.col_heading.level0 {
#   border-bottom: 1px solid white;
# }
# #T_7f28e th.col2 {
#   border-left: 1px solid white;
#   border-right: 1px solid white;
# }
# #T_7f28e td.col2 {
#   border-left: 1px solid #000066;
#   border-right: 1px solid #000066;
# }
# #T_7f28e th.col3 {
#   border-left: 1px solid white;
#   border-right: 1px solid white;
# }
# #T_7f28e td.col3 {
#   border-right: 1px solid #000066;
# }
# #T_7f28e tr.row0 {
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_7f28e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_7f28e_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_7f28e_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_7f28e_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_7f28e_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_7f28e_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_7f28e_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_7f28e_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_7f28e_level1_col4" class="col_heading level1 col4" >Tumour</th>
#       <th id="T_7f28e_level1_col5" class="col_heading level1 col5" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f28e_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_7f28e_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_7f28e_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_7f28e_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_7f28e_row0_col3" class="data row0 col3" >22</td>
#       <td id="T_7f28e_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_7f28e_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7f28e_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_7f28e_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_7f28e_row1_col1" class="data row1 col1" >439</td>
#       <td id="T_7f28e_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_7f28e_row1_col3" class="data row1 col3" >452</td>
#       <td id="T_7f28e_row1_col4" class="data row1 col4" >226</td>
#       <td id="T_7f28e_row1_col5" class="data row1 col5" >232</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Matplotlib
#
#     Pandas itself is not used to display data. It's mostly used
#     to create and maintain the Dataframe object(s). Instead, it works
#     well with other libraries so that we can create beautiful
#     clear and concise Data Projects. The standard library used to display
#     data is MatplotLib.
